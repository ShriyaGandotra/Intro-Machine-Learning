# %% [markdown]
# <a href="https://colab.research.google.com/github/ShriyaGandotra/Intro-Machine-Learning/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
drive.mount('/content/gdrive')
os.chdir('/content/gdrive/My Drive/Machine Learning/Assignment 1')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def compute_cost(X, y, theta):
    # Calculate predictions
    predictions = X.dot(theta)
    # Calculate the error
    errors = np.subtract(predictions, y)
    # Calculate the mean squared error (loss)
    sqrErrors = np.square(errors)
    # Calculate the cost function
    J = 1 / (2 * m) * np.sum(sqrErrors)
    return J

# %%
# Compute the optimal parameters using gradient descent for linear regression.
def gradient_descent(X, y, theta, alpha, iterations):
    m = len(y)  # Number of training examples
    loss = np.zeros(iterations)

    for i in range(iterations):
        # Calculate predictions
        predictions = X.dot(theta)
        # Calculate the error
        errors = np.subtract(predictions, y)
        # Calculate the gradient
        sum_delta = (alpha / m) * X.transpose().dot(errors)
        # Update parameters
        theta -= sum_delta
        # Calculate the mean squared error (loss)
        loss[i] = compute_cost(X, y, theta)

    return theta, loss

# %%
#------------------------------ QUESTION 1 ------------------------------------#

# Preprocessing input data
data = pd.read_csv('D3.csv') # Load dataset
x1 = data.values[:, 0]       # input values from first column
x2 = data.values[:, 1]       # input values from second column
x3 = data.values[:, 2]       # input values from third column
Y = data.values[:, 3]        # input values from fourth column

m = len(Y)    # Output
n1 = len(x1)  # length of x1
n2 = len(x2)  # length of x2
n3 = len(x3)  # length of x3

# %%
# Scatter plot for x1 explanatory variable
plt.scatter(x1, Y, color='red', marker='+')

# Grid, labels, and title
plt.grid(True)
plt.rcParams["figure.figsize"] = (6, 6)
plt.xlabel('explanatory variable, x1')
plt.ylabel('dependent variable, Y')
plt.title('Scatter plot for x1 ')

# Show the plot
plt.show()

# %%
# Scatter plot for x2 explanatory variable
plt.scatter(x2, Y, color='red', marker='+')

# Grid, labels, and title
plt.grid(True)
plt.rcParams["figure.figsize"] = (6, 6)
plt.xlabel('explanatory variable, x2')
plt.ylabel('dependent variable, Y')
plt.title('Scatter plot for x2')

# Show the plot
plt.show()

# %%
# Scatter plot for x3 explanatory variable
plt.scatter(x3, Y, color='red', marker='+')

# Grid, labels, and title
plt.grid(True)
plt.rcParams["figure.figsize"] = (6, 6)
plt.xlabel('explanatory variable, x3')
plt.ylabel('dependent variable, Y')
plt.title('Scatter plot for x3')

# Show the plot
plt.show()

# %%
# Linear Regression and Gradient Descent model for x1

X1_ones = np.ones((m, 1))       # A column vector of ones
X_1 = x1.reshape(m, 1)          # reshaping features (X1) to make it a 2D array suitable for matrix operations
x1 = np.hstack((X1_ones, X_1))  # horizontally stacking X1_ones and X_1 to create final feature matrix X
theta_1 = np.zeros(2)

# Lets compute the cost for theta values
cost = compute_cost(x1, Y, theta_1)

theta_1 = [0., 0.]
iterations_1 = 1500
alpha_1 = 0.01

theta_1, loss1 = gradient_descent(x1, Y, theta_1, alpha_1, iterations_1)

# Scatter plot for x1
plt.scatter(x1[:, 1], Y, color='red', marker='+', label='Training Data')

# Line plot for the linear regression model
plt.plot(x1[:, 1], x1.dot(theta_1), color='green', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (6, 6)
plt.grid(True)
plt.xlabel('explanatory variable x1')
plt.ylabel('dependent variable, Y')
plt.title('Linear Regression Fit for x1')
plt.legend()

# Show the plot
plt.show()

plt.plot(range(1, iterations_1 + 1), loss1, color='blue')
plt.rcParams["figure.figsize"] = (6, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('loss')
plt.title('Convergence of gradient descent for x1')

# Show the plot
plt.show()

# %%
# Linear Regression and Gradient Descent model for x2

X2_ones = np.ones((m, 1))      # A column vector of ones
X_2 = x2.reshape(m, 1)         # reshaping features (X2) to make it a 2D array suitable for matrix operations
x2 = np.hstack((X2_ones, X_2)) # horizontally stacking X2_ones and X_2 to create final feature matrix X
theta_2 = np.zeros(2)


# Lets compute the cost for theta values
cost = compute_cost(x2, Y, theta_2)

theta_2 = [0., 0.]
iterations_2 = 1500
alpha_2 = 0.01

theta_2, loss2 = gradient_descent(x2, Y, theta_2, alpha_2, iterations_2)

# Scatter plot for x2
plt.scatter(x2[:, 1], y=Y, color='red', marker='+', label='Training Data')

# Line plot for the linear regression model
plt.plot(x2[:, 1], x2.dot(theta_2), color='green', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (6, 6)
plt.grid(True)
plt.xlabel('explanatory variable x2')
plt.ylabel('dependent variable, Y')
plt.title('Linear Regression Fit for x2')
plt.legend()

# Show the plot
plt.show()

plt.plot(range(1, iterations_2 + 1), loss2, color='blue')
plt.rcParams["figure.figsize"] = (6, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('loss')
plt.title('Convergence of gradient descent for x2')

# Show the plot
plt.show()

# %%
# Linear Regression and Gradient Descent model for x3

X3_ones = np.ones((m, 1))      # A column vector of ones
X_3 = x3.reshape(m, 1)         # reshaping features (X3) to make it a 2D array suitable for matrix operations
x3 = np.hstack((X3_ones, X_3)) # horizontally stacking X3_ones and X_3 to create final feature matrix X
theta_3 = np.zeros(2)


# Lets compute the cost for theta values
cost = compute_cost(x3, Y, theta_3)

theta_3 = [0., 0.]
iterations_3 = 1500
alpha_3 = 0.01

theta_3, loss3 = gradient_descent(x3, Y, theta_3, alpha_3, iterations_3)

# Scatter plot for x3
plt.scatter(x3[:, 1], Y, color='red', marker='+', label='Training Data')

# Line plot for the linear regression model
plt.plot(x3[:, 1], x3.dot(theta_3), color='green', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (6, 6)
plt.grid(True)
plt.xlabel('explanatory variable x3')
plt.ylabel('dependent variable, Y')
plt.title('Linear Regression Fit for x3')
plt.legend()

# Show the plot
plt.show()

plt.plot(range(1, iterations_3 + 1), loss3, color='blue')
plt.rcParams["figure.figsize"] = (6, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('loss')
plt.title('Convergence of gradient descent for x3')

# Show the plot
plt.show()

# %%
#------------------------------ QUESTION 2 ------------------------------------#
# Multivaribale Gradient Descent

# Input data
X = data.values[:, :3]
y = data.values[:, 3]

m, n = X.shape

X_ones = np.ones((m, 1))        # A column vector of ones
X_new = X.reshape(m, n)
X = np.hstack((X_ones,X_new))

# Diffrent learning rates to explore
learning_rates = [0.1, 0.05, 0.01]

# Initialize theta to zero
theta = np.zeros(4)

# Number of iterations for gradient descent
iterations = 1500

# Lists to store loss values for each learning rate
losses = {}

# Perform gradient descent for each learning rate
for learn_r in learning_rates:
    theta_initial = np.zeros(4)
    theta_opt, loss_history = gradient_descent(X, y, theta_initial, learn_r, iterations)
    losses[learn_r] = loss_history

# Plot loss over iterations for each learning rate
for learn_r, loss_history in losses.items():
    plt.plot(range(iterations), loss_history, label=f'alpha: {learn_r}')

# Plot customizations
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss vs. Iterations for Different Learning Rates')
plt.grid(True)
plt.rcParams["figure.figsize"] = (6, 6)
plt.show()

print("Final parameters (theta): ",theta_opt,"\n")

# Predict y for new (X1, X2, X3) values
input_data = np.array([[1, 1, 1], [2, 0, 4], [3, 2, 1]])
predictions = theta_opt[0] + np.dot(input_data, theta_opt[1:])

print('Predictions for new data:')

print(input_data[0],"\t","Predicted Y: ",predictions[0])
print(input_data[1],"\t","Predicted Y: ",predictions[1])
print(input_data[2],"\t","Predicted Y: ",predictions[2])
# Out:
# Final parameters (theta):  [ 4.15118728 -1.8394291   0.72473856 -0.09513266]
#
# Predictions for new data:
# [1 1 1] 	 Predicted Y:  2.9413640816645295
# [2 0 4] 	 Predicted Y:  0.09179843075891547
# [3 2 1] 	 Predicted Y:  -0.012755552822328653
